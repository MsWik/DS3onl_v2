# %% [markdown]
# В рамках домашнего задания необходимо построить ассоциативные правила для датасета.
# Для этого будут использованы следующие алгоритмы: apriori, association_rules, fpgrowth из mlxtend.frequent_patterns (работают чуть быстрее)

# %%
import numpy as np
import pandas as pd
import seaborn as sns

from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth

# %%
df = pd.read_csv("dataset.csv", skipinitialspace=True, header=None)
df.head()
# Out:
#         0              1           2             3             4           5   \
# 0     pork  sandwich bags  lunch meat  all- purpose         flour        soda
# 1  shampoo      hand soap     waffles    vegetables       cheeses       mixes
# 2     pork           soap   ice cream  toilet paper  dinner rolls   hand soap
# 3    juice     lunch meat        soda  toilet paper  all- purpose         NaN
# 4    pasta      tortillas       mixes     hand soap  toilet paper  vegetables
#
#                 6              7                  8   \
# 0           butter     vegetables               beef
# 1             milk  sandwich bags  laundry detergent
# 2  spaghetti sauce           milk            ketchup
# 3              NaN            NaN                NaN
# 4       vegetables   paper towels         vegetables
#
#                              9             10                11         12  \
# 0                 aluminum foil  all- purpose      dinner rolls    shampoo
# 1  dishwashing liquid/detergent       waffles  individual meals  hand soap
# 2               sandwich loaves       poultry      toilet paper  ice cream
# 3                           NaN           NaN               NaN        NaN
# 4                         flour    vegetables              pork    poultry
#
#              13
# 0  all- purpose
# 1    vegetables
# 2       ketchup
# 3           NaN
# 4          eggs

# %% [markdown]
# Как видно, в данном датасете есть пропуски данных, заменим их пустой строкой

# %%
df = df.fillna ('')
df.head()
# Out:
#         0              1           2             3             4           5   \
# 0     pork  sandwich bags  lunch meat  all- purpose         flour        soda
# 1  shampoo      hand soap     waffles    vegetables       cheeses       mixes
# 2     pork           soap   ice cream  toilet paper  dinner rolls   hand soap
# 3    juice     lunch meat        soda  toilet paper  all- purpose
# 4    pasta      tortillas       mixes     hand soap  toilet paper  vegetables
#
#                 6              7                  8   \
# 0           butter     vegetables               beef
# 1             milk  sandwich bags  laundry detergent
# 2  spaghetti sauce           milk            ketchup
# 3
# 4       vegetables   paper towels         vegetables
#
#                              9             10                11         12  \
# 0                 aluminum foil  all- purpose      dinner rolls    shampoo
# 1  dishwashing liquid/detergent       waffles  individual meals  hand soap
# 2               sandwich loaves       poultry      toilet paper  ice cream
# 3
# 4                         flour    vegetables              pork    poultry
#
#              13
# 0  all- purpose
# 1    vegetables
# 2       ketchup
# 3
# 4          eggs

# %%
#составим список покупок для каждого из покупателей
shopping_list = []

for i, row in df.iterrows():
    shopping_list.append(row.loc[row != ''].unique().tolist())
    
for i in range(5):
    print(shopping_list[i])
# Out:
# ['pork', 'sandwich bags', 'lunch meat', 'all- purpose', 'flour', 'soda', 'butter', 'vegetables', 'beef', 'aluminum foil', 'dinner rolls', 'shampoo']
# ['shampoo', 'hand soap', 'waffles', 'vegetables', 'cheeses', 'mixes', 'milk', 'sandwich bags', 'laundry detergent', 'dishwashing liquid/detergent', 'individual meals']
# ['pork', 'soap', 'ice cream', 'toilet paper', 'dinner rolls', 'hand soap', 'spaghetti sauce', 'milk', 'ketchup', 'sandwich loaves', 'poultry']
# ['juice', 'lunch meat', 'soda', 'toilet paper', 'all- purpose']
# ['pasta', 'tortillas', 'mixes', 'hand soap', 'toilet paper', 'vegetables', 'paper towels', 'flour', 'pork', 'poultry', 'eggs']

# %% [markdown]
# Воспользуемся алгоритмом Apriori от mlxtend

# %%
encoder = TransactionEncoder()

transactions = pd.DataFrame(encoder.fit(shopping_list).transform(shopping_list), columns=encoder.columns_)
display(transactions.head())
# Out:
#    all- purpose  aluminum foil  bagels   beef  butter  cereals  cheeses  \
# 0          True           True   False   True    True    False    False
# 1         False          False   False  False   False    False     True
# 2         False          False   False  False   False    False    False
# 3          True          False   False  False   False    False    False
# 4         False          False   False  False   False    False    False
#
#    coffee/tea  dinner rolls  dishwashing liquid/detergent  ...  shampoo  \
# 0       False          True                         False  ...     True
# 1       False         False                          True  ...     True
# 2       False          True                         False  ...    False
# 3       False         False                         False  ...    False
# 4       False         False                         False  ...    False
#
#     soap   soda  spaghetti sauce  sugar  toilet paper  tortillas  vegetables  \
# 0  False   True            False  False         False      False        True
# 1  False  False            False  False         False      False        True
# 2   True  False             True  False          True      False       False
# 3  False   True            False  False          True      False       False
# 4  False  False            False  False          True       True        True
#
#    waffles  yogurt
# 0    False   False
# 1     True   False
# 2    False   False
# 3    False   False
# 4    False   False
#
# [5 rows x 38 columns]

# %%
# %%time
frequent_itemsets = apriori(transactions, min_support= 7/len(shopping_list), use_colnames=True, max_len = 2)
frequent_itemsets
# Out:
# Wall time: 45 ms
#       support               itemsets
# 0    0.263509         (all- purpose)
# 1    0.264176        (aluminum foil)
# 2    0.278185               (bagels)
# 3    0.262842                 (beef)
# 4    0.261508               (butter)
# ..        ...                    ...
# 736  0.062041   (waffles, tortillas)
# 737  0.068045    (yogurt, tortillas)
# 738  0.168779  (vegetables, waffles)
# 739  0.176117   (vegetables, yogurt)
# 740  0.078052      (yogurt, waffles)
#
# [741 rows x 2 columns]

# %%
rules = association_rules(frequent_itemsets, metric="lift",  min_threshold = 1.15)
display(rules.head(20))
print("Rules identified: ", len(rules))
# Out:
#                        antecedents                     consequents  \
# 0                         (fruits)                  (all- purpose)
# 1                   (all- purpose)                        (fruits)
# 2                (sandwich loaves)                        (butter)
# 3                         (butter)               (sandwich loaves)
# 4                  (sandwich bags)                       (cheeses)
# 5                        (cheeses)                 (sandwich bags)
# 6                         (fruits)  (dishwashing liquid/detergent)
# 7   (dishwashing liquid/detergent)                        (fruits)
# 8               (individual meals)  (dishwashing liquid/detergent)
# 9   (dishwashing liquid/detergent)              (individual meals)
# 10                     (hand soap)                         (mixes)
# 11                         (mixes)                     (hand soap)
# 12                       (ketchup)                          (soap)
# 13                          (soap)                       (ketchup)
# 14               (sandwich loaves)                       (shampoo)
# 15                       (shampoo)               (sandwich loaves)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.263509            0.263509  0.080720    0.306329  1.162500
# 1             0.263509            0.263509  0.080720    0.306329  1.162500
# 2             0.248833            0.261508  0.078719    0.316354  1.209731
# 3             0.261508            0.248833  0.078719    0.301020  1.209731
# 4             0.250167            0.260173  0.075384    0.301333  1.158202
# 5             0.260173            0.250167  0.075384    0.289744  1.158202
# 6             0.263509            0.268179  0.084056    0.318987  1.189458
# 7             0.268179            0.263509  0.084056    0.313433  1.189458
# 8             0.271514            0.268179  0.084056    0.309582  1.154388
# 9             0.268179            0.271514  0.084056    0.313433  1.154388
# 10            0.237492            0.273516  0.076051    0.320225  1.170773
# 11            0.273516            0.237492  0.076051    0.278049  1.170773
# 12            0.250167            0.265510  0.077385    0.309333  1.165052
# 13            0.265510            0.250167  0.077385    0.291457  1.165052
# 14            0.248833            0.248165  0.071381    0.286863  1.155936
# 15            0.248165            0.248833  0.071381    0.287634  1.155936
#
#     leverage  conviction
# 0   0.011283    1.061730
# 1   0.011283    1.061730
# 2   0.013648    1.080226
# 3   0.013648    1.074663
# 4   0.010297    1.058912
# 5   0.010297    1.055722
# 6   0.013389    1.074607
# 7   0.013389    1.072715
# 8   0.011242    1.059969
# 9   0.011242    1.061055
# 10  0.011093    1.068712
# 11  0.011093    1.056177
# 12  0.010963    1.063450
# 13  0.010963    1.058275
# 14  0.009629    1.054264
# 15  0.009629    1.054469
# Rules identified:  16

# %%
rules.nlargest(n = 10, columns = "lift")
# Out:
#                        antecedents                     consequents  \
# 2                (sandwich loaves)                        (butter)
# 3                         (butter)               (sandwich loaves)
# 6                         (fruits)  (dishwashing liquid/detergent)
# 7   (dishwashing liquid/detergent)                        (fruits)
# 10                     (hand soap)                         (mixes)
# 11                         (mixes)                     (hand soap)
# 12                       (ketchup)                          (soap)
# 13                          (soap)                       (ketchup)
# 0                         (fruits)                  (all- purpose)
# 1                   (all- purpose)                        (fruits)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 2             0.248833            0.261508  0.078719    0.316354  1.209731
# 3             0.261508            0.248833  0.078719    0.301020  1.209731
# 6             0.263509            0.268179  0.084056    0.318987  1.189458
# 7             0.268179            0.263509  0.084056    0.313433  1.189458
# 10            0.237492            0.273516  0.076051    0.320225  1.170773
# 11            0.273516            0.237492  0.076051    0.278049  1.170773
# 12            0.250167            0.265510  0.077385    0.309333  1.165052
# 13            0.265510            0.250167  0.077385    0.291457  1.165052
# 0             0.263509            0.263509  0.080720    0.306329  1.162500
# 1             0.263509            0.263509  0.080720    0.306329  1.162500
#
#     leverage  conviction
# 2   0.013648    1.080226
# 3   0.013648    1.074663
# 6   0.013389    1.074607
# 7   0.013389    1.072715
# 10  0.011093    1.068712
# 11  0.011093    1.056177
# 12  0.010963    1.063450
# 13  0.010963    1.058275
# 0   0.011283    1.061730
# 1   0.011283    1.061730

# %% [markdown]
# Воспользуемся алгоритмом fpgrowth из mlxtend.frequent_patterns

# %%
# %%time
fpgr_results = fpgrowth(transactions, min_support= 7/len(shopping_list), use_colnames=True, max_len = 2)
fpgr_results
# Out:
# Wall time: 577 ms
#       support              itemsets
# 0    0.597065          (vegetables)
# 1    0.276184          (lunch meat)
# 2    0.274183                (soda)
# 3    0.264176       (aluminum foil)
# 4    0.263509        (all- purpose)
# ..        ...                   ...
# 736  0.070047  (fruits, lunch meat)
# 737  0.071381       (fruits, pasta)
# 738  0.069380      (fruits, yogurt)
# 739  0.074049     (fruits, waffles)
# 740  0.073382     (poultry, fruits)
#
# [741 rows x 2 columns]

# %%
fpgr_rules = association_rules(fpgr_results, metric="lift",  min_threshold = 1.15)
fpgr_rules.nlargest(n = 10, columns = "lift")
# Out:
#                        antecedents                     consequents  \
# 10               (sandwich loaves)                        (butter)
# 11                        (butter)               (sandwich loaves)
# 12                        (fruits)  (dishwashing liquid/detergent)
# 13  (dishwashing liquid/detergent)                        (fruits)
# 6                      (hand soap)                         (mixes)
# 7                          (mixes)                     (hand soap)
# 8                        (ketchup)                          (soap)
# 9                           (soap)                       (ketchup)
# 14                        (fruits)                  (all- purpose)
# 15                  (all- purpose)                        (fruits)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 10            0.248833            0.261508  0.078719    0.316354  1.209731
# 11            0.261508            0.248833  0.078719    0.301020  1.209731
# 12            0.263509            0.268179  0.084056    0.318987  1.189458
# 13            0.268179            0.263509  0.084056    0.313433  1.189458
# 6             0.237492            0.273516  0.076051    0.320225  1.170773
# 7             0.273516            0.237492  0.076051    0.278049  1.170773
# 8             0.250167            0.265510  0.077385    0.309333  1.165052
# 9             0.265510            0.250167  0.077385    0.291457  1.165052
# 14            0.263509            0.263509  0.080720    0.306329  1.162500
# 15            0.263509            0.263509  0.080720    0.306329  1.162500
#
#     leverage  conviction
# 10  0.013648    1.080226
# 11  0.013648    1.074663
# 12  0.013389    1.074607
# 13  0.013389    1.072715
# 6   0.011093    1.068712
# 7   0.011093    1.056177
# 8   0.010963    1.063450
# 9   0.010963    1.058275
# 14  0.011283    1.061730
# 15  0.011283    1.061730

# %% [markdown]
# Таким образом можем сделать вывод, что оба алгоритма в результате выдают одинаковые метрики, но при этом apriori отработал быстрее, чем fpgrowth
