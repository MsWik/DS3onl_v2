# %% [markdown]
# Карпеченко Д.М., dz20, v.0.1, 04.01.2023

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import re
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder

# %% [markdown]
# Перед началом модернизировал ручками исходный датасет - убрал пробелы, кучу запятых вконце чека, ибо намучался очень сильно

# %%
data = pd.read_csv(r'D:\TeachMeSkills\DZ\dz21\dataset2.csv', names=['Items'],delimiter='.')

# %%
data
# Out:
#                                                   Items
# 0     pork,sandwichbags,lunchmeat,all-purpose,flour,...
# 1     shampoo,handsoap,waffles,vegetables,cheeses,mi...
# 2     pork,soap,icecream,toiletpaper,dinnerrolls,han...
# 3          juice,lunchmeat,soda,toiletpaper,all-purpose
# 4     pasta,tortillas,mixes,handsoap,toiletpaper,veg...
# ...                                                 ...
# 1494  beef,sandwichbags,handsoap,papertowels,paperto...
# 1495  dinnerrolls,lunchmeat,spaghettisauce,pasta,veg...
# 1496  lunchmeat,eggs,poultry,vegetables,tortillas,be...
# 1497  ketchup,milk,poultry,cheeses,soap,toiletpaper,...
# 1498    laundrydetergent,vegetables,shampoo,vegetables,
#
# [1499 rows x 1 columns]

# %%
data
# Out:
#                                                   Items
# 0     pork,sandwichbags,lunchmeat,all-purpose,flour,...
# 1     shampoo,handsoap,waffles,vegetables,cheeses,mi...
# 2     pork,soap,icecream,toiletpaper,dinnerrolls,han...
# 3          juice,lunchmeat,soda,toiletpaper,all-purpose
# 4     pasta,tortillas,mixes,handsoap,toiletpaper,veg...
# ...                                                 ...
# 1494  beef,sandwichbags,handsoap,papertowels,paperto...
# 1495  dinnerrolls,lunchmeat,spaghettisauce,pasta,veg...
# 1496  lunchmeat,eggs,poultry,vegetables,tortillas,be...
# 1497  ketchup,milk,poultry,cheeses,soap,toiletpaper,...
# 1498    laundrydetergent,vegetables,shampoo,vegetables,
#
# [1499 rows x 1 columns]

# %%
data = data['Items'].reset_index(drop=True)

# %%
data
# Out:
# 0       pork,sandwichbags,lunchmeat,all-purpose,flour,...
# 1       shampoo,handsoap,waffles,vegetables,cheeses,mi...
# 2       pork,soap,icecream,toiletpaper,dinnerrolls,han...
# 3            juice,lunchmeat,soda,toiletpaper,all-purpose
# 4       pasta,tortillas,mixes,handsoap,toiletpaper,veg...
#                               ...
# 1494    beef,sandwichbags,handsoap,papertowels,paperto...
# 1495    dinnerrolls,lunchmeat,spaghettisauce,pasta,veg...
# 1496    lunchmeat,eggs,poultry,vegetables,tortillas,be...
# 1497    ketchup,milk,poultry,cheeses,soap,toiletpaper,...
# 1498      laundrydetergent,vegetables,shampoo,vegetables,
# Name: Items, Length: 1499, dtype: object

# %%
data=data.transform(lambda x: x.split(','))

# %%
encoder = TransactionEncoder()
transactions = pd.DataFrame(encoder.fit(data).transform(data), columns=encoder.columns_)
display(transactions.head())
# Out:
#           all-purpose  aluminumfoil  bagels   beef  butter  cereals  cheeses  \
# 0  False         True          True   False   True    True    False    False
# 1  False        False         False   False  False   False    False     True
# 2  False        False         False   False  False   False    False    False
# 3  False         True         False   False  False   False    False    False
# 4  False        False         False   False  False   False    False    False
#
#    coffee/tea  dinnerrolls  ...  shampoo   soap   soda  spaghettisauce  sugar  \
# 0       False         True  ...     True  False   True           False  False
# 1       False        False  ...     True  False  False           False  False
# 2       False         True  ...    False   True  False            True  False
# 3       False        False  ...    False  False   True           False  False
# 4       False        False  ...    False  False  False           False  False
#
# ...

# %%
transactions.drop(transactions.columns[[0]], axis = 1)
# Out:
#       all-purpose  aluminumfoil  bagels   beef  butter  cereals  cheeses  \
# 0            True          True   False   True    True    False    False
# 1           False         False   False  False   False    False     True
# 2           False         False   False  False   False    False    False
# 3            True         False   False  False   False    False    False
# 4           False         False   False  False   False    False    False
# ...           ...           ...     ...    ...     ...      ...      ...
# 1494         True         False   False   True   False    False     True
# 1495        False         False   False  False   False     True     True
# 1496        False         False   False   True   False    False    False
# 1497         True         False   False   True   False    False     True
# 1498        False         False   False  False   False    False    False
#
#       coffee/tea  dinnerrolls  dishwashingliquid/detergent  ...  shampoo  \
# ...

# %%
transactions.shape
# Out:
# (1499, 39)

# %%
frequent_itemsets = apriori(transactions, min_support= 6/len(data), use_colnames=True, max_len =3)
rules = association_rules(frequent_itemsets, metric="lift",  min_threshold = 1.5)
display(rules.head(20))
print("Rules identified: ", len(rules))
# Out:
#                                       antecedents  \
# 0                       (tortillas, aluminumfoil)
# 1                                (sandwichloaves)
# 2                                 (beef, cheeses)
# 3                                  (sandwichbags)
# 4                                   (beef, mixes)
# 5                                          (pork)
# 6                       (sandwichloaves, cheeses)
# 7                                          (soap)
# 8   (dishwashingliquid/detergent, spaghettisauce)
# 9                                        (fruits)
# 10                           (toiletpaper, flour)
# 11                                         (soap)
# 12                                 (juice, mixes)
# 13                                      (ketchup)
# 14                         (sandwichloaves, pork)
# 15                                        (juice)
# 16                       (sandwichloaves, yogurt)
# 17                                        (juice)
# ...
