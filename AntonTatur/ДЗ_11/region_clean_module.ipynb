# %%
import numpy as np
#Функция очистки региона
def region_clean(region):
    if str(region)=='74':
        return "ЧЕЛЯБИНСКАЯ ОБЛ"
    if str(region)=='98':
        return "САНКТ-ПЕТЕРБУРГ"
    if 'АЛТАЙСКИЙ' in str(region):
        return 'АЛТАЙСКИЙ КРАЙ'
    if 'АМУРСКАЯ' in str(region):
        return 'АМУРСКАЯ ОБЛАСТЬ'
    if 'АРХАНГЕЛЬСКАЯ'in str(region):
        return 'АРХАНГЕЛЬСКАЯ ОБЛ'
    if 'АСТРАХАНСКАЯ' in str(region):
        return 'АСТРАХАНСКАЯ ОБЛАСТЬ'
    if 'БЕЛГОРОДСКАЯ' in str(region):
        return 'БЕЛГОРОДСКАЯ ОБЛ'
    if 'БРЯН' in str(region):
        return 'БРАНСКАЯ ОБЛ'
    if 'ВЛАДИМИРСКАЯ' in str(region):
        return 'ВЛАДИМИРСКАЯ ОБЛ'
    if 'ВОЛГОГРАДСКА' in str(region):
        return 'ВОЛГОГРАДСКАЯ ОБЛ'
    if 'ВОЛОГОДСКАЯ' in str(region):
        return 'ВОЛОГОДСКАЯ ОБЛ'
    if 'ВОРОНЕЖСК' in str(region):
        return 'ВОРОНЕЖСКАЯ ОБЛ'
    if 'ГОРЬКОВСК' in str(region):
        return 'НИЖЕГОРОДСКАЯ ОБЛ'
    if 'ГУСЬ' in str(region):
        return 'ВЛАДИМИРСКАЯ ОБЛ'
    if 'МОСКВА' in str(region):
        return 'МОСКВА'
    if 'ЕВРЕЙСК' in str(region):
        return 'ЕВРЕЙСКАЯ АО'
    if 'ЗАБАЙКАЛЬСКИ' in str(region):
        return 'ЗАБАЙКАЛЬСКИЙ КРАЙ'
    if 'ИВАНОВСКА' in str(region):
        return 'ИВАНОВСКАЯ ОБЛ'
    if 'ИРКУТСКА' in str(region):
        return 'ИРКУТСКАЯ ОБЛ'
    if 'КАБАРДИНО' in str(region):
        return 'РЕСПУБЛИКА КАБАРДИНО-БАЛКАРИЯ'
    if 'КАЛИНИНГРАДСК' in str(region):
        return 'КАЛИНИНГРАДСКАЯ ОБЛ'
    if 'КАЛУЖСК' in str(region):
        return 'КАЛУЖСКАЯ ОБЛ'
    if 'КАМЧАТСК' in str(region):
        return 'КАМЧАТСКИЙ КРАЙ'
    if 'КАРАЧАЕВО' in str(region):
        return 'РЕСПУБЛИКА КАРАЧАЕВО-ЧЕРКЕССИЯ'
    if 'КЕМЕРОВСКА' in str(region):
        return 'КЕМЕРОВСМКАЯ ОБЛ'
    if 'КИРОВСКА' in str(region):
        return 'КИРОВСКАЯ ОБЛ'
    if 'КОСТРОМСКА' in str(region):
        return 'КОСТРОМСКАЯ ОБЛ'
    if 'КРАСНОДАРСК' in str(region):
        return 'КРАСНОДАРСКИЙ КРАЙ'
    if 'КРАСНОЯРСКИ' in str(region):
        return 'КРАСНОЯРСКИЙ КРАЙ'
    if 'КУРГАНСКА' in str(region):
        return 'КУРГАНСКАЯ ОБЛ'
    if 'КУРСК' in str(region):
        return 'КУРСКАЯ ОБЛ'
    if 'ЛЕНИНГРАДСКА' in str(region):
        return 'ЛЕНИГРАДСКАЯ ОБЛ'
    if 'ЛИПЕЦКА' in str(region):
        return 'ЛИПЕЦКАЯ ОБЛ'
    if 'МАГАДАНСКА' in str(region):
        return 'МАГАДАНСКАЯ ОБЛ'
    if 'МОСКОВСК' in str(region) or 'МОСКВ' in str(region) or 'МЫТИЩИ' in str(region):
        return 'МОСКОВСКАЯ ОБЛ'
    if 'МУРМАНСКА' in str(region):
        return 'МУРМАНСКАЯ ОБЛ'
    if 'НЕНЕЦКИ' in str(region):
        return 'ЯМАЛО-НЕНЕЦИЙ АО'
    if 'НИЖЕГОРОДСК' in str(region):
        return 'НИЖЕГОРОДСКАЯ ОБЛ'
    if 'НОВГОРОДСК' in str(region):
        return 'НОВГОРОДОСКАЯ ОБЛ'
    if 'НОВОСИБИРСКА' in str(region):
        return 'НОВОСИБИРСКАЯ ОБЛ'
    if 'ОМСКА' in str(region):
        return 'ОМСКАЯ ОБЛ'
    if 'ОРЕНБУРГСКА' in str(region):
        return 'ОРЕНБУРГСКАЯ ОБЛ'
    if 'ОРЛОВСКА' in str(region) or 'ОРЁЛ' in str(region):
        return 'ОРЛОВКАЯ ОБЛ'
    if 'ПЕНЗЕНСК' in str(region):
        return 'ПЕНЗЕНСКАЯ ОБЛ'
    if 'ПЕРМСК' in str(region):
        return 'ПЕРМСКИЙ КРАЙ'
    if 'ПРИМОРСКИ' in str(region):
        return 'ПРИМОРСКИЙ КРАЙ'
    if 'ПСКОВСК' in str(region):
        return 'ПСКОВСКАЯ ОБЛ'
    if 'АДЫГЕЯ' in str(region):
        return 'РЕСПУБЛИКА АДЫГЕЯ'
    if 'АЛТАЙ' in str(region):
        return 'РЕСПУБЛИКА АЛТАЙ'
    if 'БАШКОРТО' in str(region):
        return 'РЕСПУБЛИКА БАШКОРТОСТАН'
    if 'БУРЯТ' in str(region):
        return 'РЕСПУБЛИКА БУРЯТИЯ'
    if 'ДАГЕСТ' in str(region):
        return 'РЕСПУБЛИКА ДАГЕСТАН'
    if 'ИНГУШ' in str(region):
        return 'РЕСПУБЛИКА ИНГУШЕТИЯ'
    if 'КАЛМЫК' in str(region):
        return 'РЕСПУБЛИКА КАЛМЫКИЯ'
    if 'КАРЕЛ' in str(region):
        return 'РЕСПУБЛИКА КАРЕЛИЯ'
    if 'КОМИ' in str(region):
        return 'РЕСПУБЛИКА КОМИ'
    if 'КРЫМ' in str(region):
        return 'РЕСПУБЛИКА КРЫМ'
    if 'МАРИЙ' in str(region):
        return 'РЕСПУБЛИКА МАРИЙ ЭЛ'
    if 'МОРДОВИ' in str(region):
        return 'РЕСПУБЛИКА МОРДОВИЯ'
    if 'САХА' in str(region):
        return 'РЕСПУБЛИКА САХА'
    if 'ОСЕТИЯ' in str(region):
        return 'РЕСПУБЛИКА СЕВЕРНАЯ ОСЕТИЯ'
    if 'ТАТАРСТАН' in str(region):
        return 'РЕСПУБЛИКА ТАТАРСТАН'
    if 'ТЫВА' in str(region):
        return 'РЕСПУБЛИКА ТЫВА'
    if 'ХАКАС' in str(region):
        return 'РЕСПУБЛИКА ХАКАСИЯ'
    if 'РОСТОВСК' in str(region):
        return 'РОСТОВСКАЯ ОБЛ'
    if 'РЯЗАНС' in str(region):
        return 'РЯЗАНСКАЯ ОБЛ'
    if 'САМАРСК' in str(region):
        return 'САМАРСКАЯ ОБЛ'
    if 'САНКТ' in str(region):
        return 'САНКТ-ПЕТЕРБУРГ'
    if 'САРАТОВСК' in str(region):
        return 'САРАТОВСКАЯ ОБЛ'
    if 'САХАЛИНСК' in str(region):
        return 'САХАЛИНСКАЯ ОБЛ'
    if 'СВЕРДЛОВСК' in str(region):
        return 'СВЕРДЛОВСКАЯ ОБЛ'
    if 'СЕВАСТОП' in str(region):
        return 'СЕВАСТОПОЛЬ'
    if 'СМОЛЕНСКА' in str(region):
        return 'СМОЛЕНСКАЯ ОБЛ'
    if 'СТАВРОПОЛЬСК' in str(region):
        return 'СТАВРОПОЛЬСКИЙ КРАЙ'
    if 'ТАМБОВСК' in str(region):
        return 'ТАМБОВСКАЯ ОБЛ'
    if 'ТВЕРСК' in str(region):
        return 'ТВЕРСКАЯ ОБЛ'
    if 'ТОМСКА' in str(region):
        return 'ТОМСКАЯ ОБЛ'
    if 'ТУЛЬСКА' in str(region):
        return 'ТУЛЬСКАЯ ОБЛ'
    if 'ТЮМЕНСК' in str(region):
        return 'ТЮМЕНСКАЯ ОБ'
    if 'УДМУР' in str(region):
        return 'РЕСПУБЛИКА УДМУРТИЯ'
    if 'УЛЬЯНОВСКА' in str(region):
        return 'УЛЬЯНОВСКАЯ ОБЛ'
    if 'ХАБАРОВСКИ' in str(region):
        return 'ХАБАРОВСКИЙ КРАЙ'
    if 'ХАНТЫ' in str(region):
        return 'ХАНТЫ-МАНСКИЙСКИЙ АО'
    if 'ЧЕЛЯБИНСКА' in str(region):
        return 'ЧЕЛЯБИНСКАЯ ОБЛ'
    if 'ЧЕЧН' in str(region) or 'ЧЕЧНЯ' in str(region) or 'ЧЕЧЕН' in str(region):
        return 'РЕСПУБЛИКА ЧЕЧНЯ'
    if 'ЧУВАШ' in str(region):
        return 'РЕСПУБЛИКА ЧУВАШИЯ'
    if 'ЧУКОТ' in str(region):
        return 'ЧУКОТСКИЙ АО'
    if 'ЧИТИН' in str(region):
        return 'ЗАБАЙКАЛЬСКИЙ КРАЙ'
    if 'ЯМАЛО' in str(region):
        return 'ЯМАЛО-НЕНЕЦКИЙ АО'
    if 'ЯРОСЛАВСК' in str(region):
        return 'ЯРОСЛАВСКАЯ ОБЛ'
    if 'ЭВЕНКИЙ' in str(region):
        return 'КРАСНОЯРСКИЙ КРАЙ'
    return np.nan
