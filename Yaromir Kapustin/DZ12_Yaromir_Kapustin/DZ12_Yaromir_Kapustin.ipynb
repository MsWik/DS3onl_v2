# %% [markdown]
# * 02.11.2022
# * Yaromir Kapustin
# * v.02

# %% [markdown]
# В данной задаче нам представлены данные в которых ключевое поле — это то, просрочит ли клиент микро-финансовой организации выплату более чем на 60 дней или нет.
# Нам нужно построить модель, которая по входным данным предсказывала бы с максимальной точностью ключе-вой параметр.
# Основной параметр это delinq60plus. Остальные парамет-ры интуитивно понятны из таблиц.
# #### Цель
#
# Построить модель машинного обучения для предсказания вероятности того, что клиент уйдет в просрочку более 60 дней.
#
# #### Задача
# осуществить корректную загрузку данных
# осуществить разведывательный анализ данных:
# - разбить выборку на обучающую и тестовую
# - проанализировать пропуски и решить, что с ними делать
# - проанализировать выбросы
# - создать/ удалить переменные
# - закодировать категориальные переменные
# - нормализовать числовые переменные (при необходимости)
#
# построить модель и оценить ее качество
# при необходимости вернуться к предыдущим шагам, чтобы улучшить качество модели
#
# #### Высокая цель. Использовать (не везде, а где мы работаем с данными напрямую) SQL запросы.
#
#
#
#
#
#
#
#
# # ДЗ12
# Использовать полученные знания в части обучения моделей для обучения и подбора параметров в задачах из предыдущих ДЗ на выбор (мфо, задача с тем возьмёт ли человек кредит или нет)
# В частности использовать:
#
#
# GaussianNB
# LinearRegression + PolynomialFeatures.
# При обучении использовать make_pipeline
# GridSearchCV для поиска параметров
# Дедлайн - 1 занятие.
#
# ---

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import shapiro
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
import sqlite3

# %%
conn = sqlite3.connect('test.db')
df = pd.read_csv(r'MFOcredit.csv', sep=';')

# %%
df.head()
# Out:
#    id   date_start     date_end   gender  age          auto  \
# 0   1  03-Jan-2013  12-Jan-2013  Мужской   44           Нет
# 1   2  03-Jan-2013  17-Jan-2013  Мужской   21  Пропуск поля
# 2   3  03-Jan-2013  17-Jan-2013  Мужской   25  Пропуск поля
# 3   4  03-Jan-2013  17-Jan-2013  Женский   47  Пропуск поля
# 4   5  03-Jan-2013  17-Jan-2013  Мужской   22           Нет
#
#               housing                       marstatus regclient      jobtype  \
# 0         Собственное  Гражданский брак/женат/замужем       Нет  Официальное
# 1  Живут с родителями                          Холост       Нет  Официальное
# 2         Собственное                          Холост        Да  Официальное
# 3         Собственное  Гражданский брак/женат/замужем        Да  Официальное
# 4          Арендуемое  Гражданский брак/женат/замужем       Нет  Официальное
#
#                       region       credits children delinq60plus
# 0      Новосибирская область           Нет       Да          Нет
# 1     Кемеровская область юг            Да      Нет          Нет
# 2  Кемеровская область север  Пропуск поля      Нет          Нет
# 3  Кемеровская область север           Нет      Нет          Нет
# 4  Кемеровская область север            Да       Да          Нет

# %%
df.to_sql('MFOcredit', conn, index=False, if_exists='replace')
# Out:
# 35212

# %%
def select(sql):
  return pd.read_sql(sql, conn)

# %% [markdown]
# ## Чистка датасета

# %%
#часто встречается значение "Пропуск поля", заменю его на NaN. А также Да и Нет на 1 и 0
df.replace(to_replace = "Пропуск поля", value = np.nan, inplace=True)
df.replace(to_replace = "Нет", value = 0, inplace=True)
df.replace(to_replace = "Да", value = 1, inplace=True)

# %%
# вижу, что некоторые колонки содержат пропуски
sql = '''SELECT * FROM MFOcredit AS t'''
select(sql)
# Out:
#           id   date_start     date_end   gender  age          auto  \
# 0          1  03-Jan-2013  12-Jan-2013  Мужской   44           Нет
# 1          2  03-Jan-2013  17-Jan-2013  Мужской   21  Пропуск поля
# 2          3  03-Jan-2013  17-Jan-2013  Мужской   25  Пропуск поля
# 3          4  03-Jan-2013  17-Jan-2013  Женский   47  Пропуск поля
# 4          5  03-Jan-2013  17-Jan-2013  Мужской   22           Нет
# ...      ...          ...          ...      ...  ...           ...
# 35207  35208  03-Jan-2014  17-Jan-2014  Мужской   30            Да
# 35208  35209  03-Jan-2014  17-Jan-2014  Женский   57           Нет
# 35209  35210  03-Jan-2014  17-Jan-2014  Женский   38  Пропуск поля
# 35210  35211  03-Jan-2014  17-Jan-2014  Женский   19  Пропуск поля
# 35211  35212  03-Jan-2014  17-Jan-2014  Мужской   25  Пропуск поля
#
#                      housing                       marstatus regclient  \
# 0                Собственное  Гражданский брак/женат/замужем       Нет
# 1         Живут с родителями                          Холост       Нет
# 2                Собственное                          Холост        Да
# 3                Собственное  Гражданский брак/женат/замужем        Да
# 4                 Арендуемое  Гражданский брак/женат/замужем       Нет
# ...                      ...                             ...       ...
# 35207  Долевая собственность  Гражданский брак/женат/замужем        Да
# 35208            Собственное                        Разведен        Да
# 35209           Пропуск поля                    Пропуск поля        Да
# 35210           Пропуск поля                    Пропуск поля        Да
# 35211           Пропуск поля                    Пропуск поля        Да
#
#             jobtype                     region       credits children  \
# 0       Официальное      Новосибирская область           Нет       Да
# 1       Официальное     Кемеровская область юг            Да      Нет
# 2       Официальное  Кемеровская область север  Пропуск поля      Нет
# 3       Официальное  Кемеровская область север           Нет      Нет
# 4       Официальное  Кемеровская область север            Да       Да
# ...             ...                        ...           ...      ...
# 35207   Официальное             Алтайский край            Да       Да
# 35208  Пропуск поля             Алтайский край            Да      Нет
# 35209  Пропуск поля      Новосибирская область           Нет       Да
# 35210  Пропуск поля     Кемеровская область юг           Нет      Нет
# 35211  Пропуск поля  Кемеровская область север           Нет      Нет
#
#       delinq60plus
# 0              Нет
# 1              Нет
# 2              Нет
# 3              Нет
# 4              Нет
# ...            ...
# 35207          Нет
# 35208          Нет
# 35209          Нет
# 35210          Нет
# 35211          Нет
#
# [35212 rows x 14 columns]

# %%
#повторяющихся строк нет
df.drop_duplicates()
# Out:
#           id   date_start     date_end   gender  age  auto  \
# 0          1  03-Jan-2013  12-Jan-2013  Мужской   44   0.0
# 1          2  03-Jan-2013  17-Jan-2013  Мужской   21   NaN
# 2          3  03-Jan-2013  17-Jan-2013  Мужской   25   NaN
# 3          4  03-Jan-2013  17-Jan-2013  Женский   47   NaN
# 4          5  03-Jan-2013  17-Jan-2013  Мужской   22   0.0
# ...      ...          ...          ...      ...  ...   ...
# 35207  35208  03-Jan-2014  17-Jan-2014  Мужской   30   1.0
# 35208  35209  03-Jan-2014  17-Jan-2014  Женский   57   0.0
# 35209  35210  03-Jan-2014  17-Jan-2014  Женский   38   NaN
# 35210  35211  03-Jan-2014  17-Jan-2014  Женский   19   NaN
# 35211  35212  03-Jan-2014  17-Jan-2014  Мужской   25   NaN
#
#                      housing                       marstatus  regclient  \
# 0                Собственное  Гражданский брак/женат/замужем          0
# 1         Живут с родителями                          Холост          0
# 2                Собственное                          Холост          1
# 3                Собственное  Гражданский брак/женат/замужем          1
# 4                 Арендуемое  Гражданский брак/женат/замужем          0
# ...                      ...                             ...        ...
# 35207  Долевая собственность  Гражданский брак/женат/замужем          1
# 35208            Собственное                        Разведен          1
# 35209                    NaN                             NaN          1
# 35210                    NaN                             NaN          1
# 35211                    NaN                             NaN          1
#
#            jobtype                     region  credits  children  delinq60plus
# 0      Официальное      Новосибирская область      0.0       1.0             0
# 1      Официальное     Кемеровская область юг      1.0       0.0             0
# 2      Официальное  Кемеровская область север      NaN       0.0             0
# 3      Официальное  Кемеровская область север      0.0       0.0             0
# 4      Официальное  Кемеровская область север      1.0       1.0             0
# ...            ...                        ...      ...       ...           ...
# 35207  Официальное             Алтайский край      1.0       1.0             0
# 35208          NaN             Алтайский край      1.0       0.0             0
# 35209          NaN      Новосибирская область      0.0       1.0             0
# 35210          NaN     Кемеровская область юг      0.0       0.0             0
# 35211          NaN  Кемеровская область север      0.0       0.0             0
#
# [35212 rows x 14 columns]

# %%
#пропуски в %: auto 40%, housing 22%, marstatus 21%, jobtype 41%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print(col, round(pct_missing*100))
# Out:
# id 0
# date_start 0
# date_end 0
# gender 0
# age 0
# auto 40
# housing 22
# marstatus 21
# regclient 0
# jobtype 41
# region 0
# credits 3
# children 2
# delinq60plus 0

# %%
#удалю auto и jobtype, поскольки слишком много пропусков. Колонки неинформативны. А также колонку id
cols_to_drop = ["auto", "jobtype", "id"]
df = df.drop(cols_to_drop, axis=1)

# %%
#меняю формат даты
df['date_start'] = pd.to_datetime(df['date_start'], format="%d-%b-%Y")
df['date_end'] = pd.to_datetime(df['date_end'], format="%d-%b-%Y")

# %%
#datetime64[ns] to float
df[('date_start')] = df[('date_start')].values.astype("float64")
df[('date_end')] = df[('date_end')].values.astype("float64")

# %%
# заменяю пустые значения наиболее встречающимся
imputer = SimpleImputer(strategy='most_frequent')
df[['housing']] = imputer.fit_transform(df[['housing']])
df[['marstatus']] = imputer.fit_transform(df[['marstatus']])
df[['credits']] = imputer.fit_transform(df[['credits']])
df[['children']] = imputer.fit_transform(df[['children']])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35212 entries, 0 to 35211
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date_start    35212 non-null  float64
#  1   date_end      35212 non-null  float64
#  2   gender        35212 non-null  object
#  3   age           35212 non-null  int64
#  4   housing       35212 non-null  object
#  5   marstatus     35212 non-null  object
#  6   regclient     35212 non-null  int64
#  7   region        35212 non-null  object
#  8   credits       35212 non-null  float64
#  9   children      35212 non-null  float64
#  10  delinq60plus  35212 non-null  int64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 3.0+ MB

# %%
# есть небольшая обратная корреляция основного параматра с датами выдачи и погашения займа
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
# преобразую категориальные признаки
df = pd.concat([df, 
                      pd.get_dummies(df['housing'], prefix="housing"),
                      pd.get_dummies(df['marstatus'], prefix="marstatus"),
                      pd.get_dummies(df['gender'], prefix="gender"),
                      pd.get_dummies(df['region'], prefix="region")],
                     axis=1)

# %%
# удаляю лишние колонки
df.drop(['housing','marstatus','gender', 'region'], axis=1, inplace=True)

# %%
# Итоговый результат
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35212 entries, 0 to 35211
# Data columns (total 23 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   date_start                                35212 non-null  float64
#  1   date_end                                  35212 non-null  float64
#  2   age                                       35212 non-null  int64
#  3   regclient                                 35212 non-null  int64
#  4   credits                                   35212 non-null  float64
#  5   children                                  35212 non-null  float64
#  6   delinq60plus                              35212 non-null  int64
#  7   housing_Арендуемое                        35212 non-null  uint8
#  8   housing_Долевая собственность             35212 non-null  uint8
#  9   housing_Живут с родителями                35212 non-null  uint8
#  10  housing_Муниципальное                     35212 non-null  uint8
#  11  housing_Собственное                       35212 non-null  uint8
#  12  marstatus_Вдова/вдовец                    35212 non-null  uint8
#  13  marstatus_Гражданский брак/женат/замужем  35212 non-null  uint8
#  14  marstatus_Разведен                        35212 non-null  uint8
#  15  marstatus_Холост                          35212 non-null  uint8
#  16  gender_Женский                            35212 non-null  uint8
#  17  gender_Мужской                            35212 non-null  uint8
#  18  region_Алтайский край                     35212 non-null  uint8
#  19  region_Кемеровская область север          35212 non-null  uint8
#  20  region_Кемеровская область юг             35212 non-null  uint8
#  21  region_Красноярский край                  35212 non-null  uint8
#  22  region_Новосибирская область              35212 non-null  uint8
# dtypes: float64(4), int64(3), uint8(16)
# memory usage: 2.4 MB

# %% [markdown]
# ## Нормализация

# %%
#разницы между MinMax и StandardScaler нету. AUC такой же
scaler = preprocessing.StandardScaler()

# %%
# нормализую даты и возраст
df[['date_start','date_end']] = scaler.fit_transform(df[['date_start','date_end']])
df[['age']] = scaler.fit_transform(df[['age']])

# %%
df
# Out:
#        date_start  date_end       age  regclient  credits  children  \
# 0       -2.110705 -2.179596  0.512484          0      0.0       1.0
# 1       -2.110705 -2.130962 -1.232085          0      1.0       0.0
# 2       -2.110705 -2.130962 -0.928681          1      0.0       0.0
# 3       -2.110705 -2.130962  0.740037          1      0.0       0.0
# 4       -2.110705 -2.130962 -1.156234          0      1.0       1.0
# ...           ...       ...       ...        ...      ...       ...
# 35207    1.414511  1.419323 -0.549427          1      1.0       1.0
# 35208    1.414511  1.419323  1.498545          1      1.0       0.0
# 35209    1.414511  1.419323  0.057379          1      0.0       1.0
# 35210    1.414511  1.419323 -1.383786          1      0.0       0.0
# 35211    1.414511  1.419323 -0.928681          1      0.0       0.0
#
#        delinq60plus  housing_Арендуемое  housing_Долевая собственность  \
# 0                 0                   0                              0
# 1                 0                   0                              0
# 2                 0                   0                              0
# 3                 0                   0                              0
# 4                 0                   1                              0
# ...             ...                 ...                            ...
# 35207             0                   0                              1
# 35208             0                   0                              0
# 35209             0                   0                              0
# 35210             0                   0                              0
# 35211             0                   0                              0
#
#        housing_Живут с родителями  ...  \
# 0                               0  ...
# 1                               1  ...
# 2                               0  ...
# 3                               0  ...
# 4                               0  ...
# ...                           ...  ...
# 35207                           0  ...
# 35208                           0  ...
# 35209                           0  ...
# 35210                           0  ...
# 35211                           0  ...
#
#        marstatus_Гражданский брак/женат/замужем  marstatus_Разведен  \
# 0                                             1                   0
# 1                                             0                   0
# 2                                             0                   0
# 3                                             1                   0
# 4                                             1                   0
# ...                                         ...                 ...
# 35207                                         1                   0
# 35208                                         0                   1
# 35209                                         1                   0
# 35210                                         1                   0
# 35211                                         1                   0
#
#        marstatus_Холост  gender_Женский  gender_Мужской  \
# 0                     0               0               1
# 1                     1               0               1
# 2                     1               0               1
# 3                     0               1               0
# 4                     0               0               1
# ...                 ...             ...             ...
# 35207                 0               0               1
# 35208                 0               1               0
# 35209                 0               1               0
# 35210                 0               1               0
# 35211                 0               0               1
#
#        region_Алтайский край  region_Кемеровская область север  \
# 0                          0                                 0
# 1                          0                                 0
# 2                          0                                 1
# 3                          0                                 1
# 4                          0                                 1
# ...                      ...                               ...
# 35207                      1                                 0
# 35208                      1                                 0
# 35209                      0                                 0
# 35210                      0                                 0
# 35211                      0                                 1
#
#        region_Кемеровская область юг  region_Красноярский край  \
# 0                                  0                         0
# 1                                  1                         0
# 2                                  0                         0
# 3                                  0                         0
# 4                                  0                         0
# ...                              ...                       ...
# 35207                              0                         0
# 35208                              0                         0
# 35209                              0                         0
# 35210                              1                         0
# 35211                              0                         0
#
#        region_Новосибирская область
# 0                                 1
# 1                                 0
# 2                                 0
# 3                                 0
# 4                                 0
# ...                             ...
# 35207                             0
# 35208                             0
# 35209                             1
# 35210                             0
# 35211                             0
#
# [35212 rows x 23 columns]

# %% [markdown]
# ## Построение модели

# %% [markdown]
# > RFC

# %%
y = df['delinq60plus']
x = df.drop(('delinq60plus'), axis=1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.7, random_state=21)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators = 50,  max_depth=9, min_samples_leaf=2, min_samples_split=8, random_state=42)
rfc.fit(x_train, y_train)
rfc.score(x_test, y_test)
# Out:
# 0.770257478227944

# %%
#подбор гиперпараметров
from sklearn.model_selection import GridSearchCV
parametrs = { 'n_estimators': range (10,51,10),
              'max_depth': range (1,13,2),
              'min_samples_leaf': range (1,8),
              'min_samples_split': range (2,10,2) }

grid = GridSearchCV(rfc, parametrs).fit(x_train, y_train)
grid.best_params_
# Out:
# {'max_depth': 7,
#  'min_samples_leaf': 7,
#  'min_samples_split': 2,
#  'n_estimators': 50}

# %%
y_pred = rfc.predict_proba(x_test)[:, 1]
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test, y_pred)
# Out:
# 0.8563868785697474

# %% [markdown]
# > CatBoostClassifier

# %%
from catboost import Pool, CatBoostClassifier

# %%
model = CatBoostClassifier(iterations=10,
                           learning_rate=1,
                           depth=2,
                           loss_function='MultiClass')

# %%
model.fit(x_train, y_train)
model.score(x_test, y_test)
# Out:
# 0:	learn: 0.5210490	total: 3.04ms	remaining: 27.4ms
# 1:	learn: 0.4910333	total: 5.57ms	remaining: 22.3ms
# 2:	learn: 0.4693960	total: 7.84ms	remaining: 18.3ms
# 3:	learn: 0.4669633	total: 10.2ms	remaining: 15.4ms
# 4:	learn: 0.4584869	total: 12.9ms	remaining: 12.9ms
# 5:	learn: 0.4561415	total: 15.2ms	remaining: 10.1ms
# 6:	learn: 0.4515071	total: 17.6ms	remaining: 7.53ms
# 7:	learn: 0.4502040	total: 19.9ms	remaining: 4.97ms
# 8:	learn: 0.4497214	total: 22.2ms	remaining: 2.46ms
# 9:	learn: 0.4491387	total: 24.5ms	remaining: 0us
# 0.7659030670200682

# %%
y_pred = model.predict_proba(x_test)[:, 1]
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test, y_pred)
# Out:
# 0.8495880455093507

# %% [markdown]
# # ДЗ12

# %% [markdown]
# > Линейная регрессия

# %%
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import roc_auc_score

# %%
grid_values = {"fit_intercept": [True, False],
               "normalize": [True, False],
              }
search = GridSearchCV(LinearRegression(), grid_values, cv = 5, n_jobs=2)
search.fit(x_train, y_train)

search.best_params_
# Out:
# C:\conda\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# {'fit_intercept': True, 'normalize': True}

# %%
clf = make_pipeline(PolynomialFeatures(), GridSearchCV(LinearRegression(), grid_values, cv = 5, n_jobs=2))

# %%
clf.fit(x_train, y_train)
clf_proba = clf.predict(x_test)
roc_auc_score(y_test, clf_proba)
# Out:
# C:\conda\lib\site-packages\sklearn\linear_model\_base.py:148: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2. Please leave the normalize parameter to its default value to silence this warning. The default behavior of this estimator is to not do any normalization. If normalization is needed please use sklearn.preprocessing.StandardScaler instead.
#   warnings.warn(
# 0.858287693269853

# %%
#без PolynomialFeatures
model = LinearRegression()

# %%
model.fit(x_train, y_train)
model_proba = model.predict(x_test)
roc_auc_score(y_test, model_proba)
# Out:
# 0.7301242494243025

# %% [markdown]
# > Наивный Байесовский классификатор

# %%
model = GaussianNB()
param_grid = {'var_smoothing': np.logspace(0,-9, num=100)}

# %%
ngc = make_pipeline(PolynomialFeatures(), GridSearchCV(estimator = model, 
                     param_grid = param_grid, 
                     cv = 5, 
                     verbose = 1, 
                     scoring='accuracy'))

# %%
ngc.fit(x_train, y_train)
ngc_proba = ngc.predict_proba(x_test)[:,1]
roc_auc_score(y_test, ngc_proba)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# 0.8282930530638632

# %%
#без PolynomialFeatures
model = GaussianNB(var_smoothing = 0.0533669923120631)

# %%
model.fit(x_train, y_train)
model_proba = model.predict_proba(x_test)[:,1]
roc_auc_score(y_test, model_proba)
# Out:
# 0.8291302426139204
